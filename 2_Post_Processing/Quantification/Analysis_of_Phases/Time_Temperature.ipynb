# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import matplotlib.patches as patches
from scipy.io import loadmat
from matplotlib.colors import ListedColormap
from matplotlib.lines import Line2D
from matplotlib.text import Text
from matplotlib.legend_handler import HandlerLine2D

# %%
path_np = os.path.abspath('../../../1_Simulation_Results/numpy_files/')

colormap_data = loadmat('../cold2hot.mat')
cold2hot = ListedColormap(colormap_data['colormap'])
hot2cold = ListedColormap(colormap_data['colormap'][::-1])

# %%
timeS_GT = np.load(path_np+'/Gaussian/TDB/time.npy')
temp_GT = np.load(path_np+'/Gaussian/TDB/temp.npy')
LIQ_GT = np.load(path_np+'/Gaussian/TDB/LIQ.npy')
timeS_GF = np.load(path_np+'/Gaussian/Fitting/time.npy')
temp_GF = np.load(path_np+'/Gaussian/Fitting/temp.npy')

timeS_FT = np.load(path_np+'/FlatTop/TDB/time.npy')
temp_FT = np.load(path_np+'/FlatTop/TDB/temp.npy')
timeS_FF = np.load(path_np+'/FlatTop/Fitting/time.npy')
temp_FF = np.load(path_np+'/FlatTop/Fitting/temp.npy')

timeS_RT = np.load(path_np+'/Ring/TDB/time.npy')
temp_RT = np.load(path_np+'/Ring/TDB/temp.npy')
timeS_RF = np.load(path_np+'/Ring/Fitting/time.npy')
temp_RF = np.load(path_np+'/Ring/Fitting/temp.npy')

timeS_BT = np.load(path_np+'/Bessel/TDB/time.npy')
temp_BT = np.load(path_np+'/Bessel/TDB/temp.npy')
timeS_BF = np.load(path_np+'/Bessel/Fitting/time.npy')
temp_BF = np.load(path_np+'/Bessel/Fitting/temp.npy')

# %%
fig, ((ax1, ax2),(ax3, ax4)) = plt.subplots(2, 2, figsize=[16, 12], frameon=False)
ax1.set_facecolor((0, 0, 0, 0))

ax1.plot(timeS_GT, temp_GT[0,200,:], linestyle='-', linewidth=4, color='red', label=r'GHS$\mathbf{_{\psi}}$')
ax1.plot(timeS_RT, temp_RT[0,200,:], linestyle='--', linewidth=4, color='magenta', label=r'RHS$\mathbf{_{\psi}}$')

ax2.plot(timeS_GF, temp_GF[0,200,:], linestyle='-', linewidth=4, color='green', label=r'GHS$\mathbf{_{\theta}}$')
ax2.plot(timeS_BT, temp_BT[0,200,:], linestyle='--', linewidth=4, color='darkorchid', label=r'BHS$\mathbf{_{\psi}}$')

ax3.plot(timeS_FT, temp_FT[0,200,:], linestyle='-', linewidth=4, color='blue', label=r'FTHS$\mathbf{_{\psi}}$')
ax3.plot(timeS_RF, temp_RF[0,200,:], linestyle='--', linewidth=4, color='navy', label=r'RHS$\mathbf{_{\theta}}$')

ax4.plot(timeS_FF, temp_FF[0,200,:], linestyle='-', linewidth=4, color='darkorange', label=r'FTHS$\mathbf{_{\theta}}$')
ax4.plot(timeS_BF, temp_BF[0,200,:], linestyle='--', linewidth=4, color='brown', label=r'BHS$\mathbf{_{\theta}}$')

ax1.legend( prop={'weight':'bold', 'size':'15',}, )
ax2.legend( prop={'weight':'bold', 'size':'15',}, )
ax3.legend( prop={'weight':'bold', 'size':'15',}, )
ax4.legend( prop={'weight':'bold', 'size':'15',}, )
plt.show()

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=[16, 12], frameon=False)
ax1.set_facecolor((0, 0, 0, 0))
ax2.set_facecolor((0, 0, 0, 0))
ax3.set_facecolor((0, 0, 0, 0))
ax4.set_facecolor((0, 0, 0, 0))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.35, hspace=0.5)

x = int((401/1000)*500) # x-coordinate of point of interest
y = 0 # y coordinate of point of interest ## origin is at top left corner

GT, = ax1.plot(timeS_GT, temp_GT[0,200,:], linewidth=5, linestyle='-',  color='blue', label=r'Gaussian$\mathbf{_{\psi}}$')
RT, = ax1.plot(timeS_RT, temp_RT[0,200,:], linewidth=5, linestyle='--',  color = 'r', label =r'Ring$\mathbf{_{\psi}}$')
ax1.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax1.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax1.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax1.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax1.set_ylim(100, 3100)
ax1.set_xlim(-2, 29)
ax1.spines[:].set_linewidth(4)
ax1.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_GR = ax1.legend(loc=(0.55, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={GT: HandlerLine2D(numpoints=3), RT: HandlerLine2D(numpoints=3)}, handletextpad=0.1, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_GR.get_lines()]

GF, = ax2.plot(timeS_GF, temp_GF[0,200,:], linewidth=5, linestyle='-',  color = 'green', label =r'Gaussian$\mathbf{_{\theta}}$')
BT, = ax2.plot(timeS_BT, temp_BT[0,200,:], linewidth=5, linestyle='--',  color='hotpink', label=r'Bessel$\mathbf{_{\psi}}$')
ax2.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax2.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax2.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax2.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax2.set_ylim(100, 3100)
ax2.set_xlim(-2, 29)
ax2.spines[:].set_linewidth(4)
ax2.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_GB = ax2.legend(loc=(0.55, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={GF: HandlerLine2D(numpoints=3), BT: HandlerLine2D(numpoints=3)}, handletextpad=0.1, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_GB.get_lines()]


FT, = ax3.plot(timeS_FT, temp_FT[0,200,:], linewidth=5, linestyle='-',  color = 'darkorange', label =r'FlatTop$\mathbf{_{\psi}}$')
RF, = ax3.plot(timeS_RF, temp_RF[0,200,:], linewidth=5, linestyle='--',  color='navy', label=r'Ring$\mathbf{_{\theta}}$')
ax3.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax3.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax3.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax3.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax3.set_ylim(100, 3100)
ax3.set_xlim(-2, 29)
ax3.spines[:].set_linewidth(4)
ax3.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_FR = ax3.legend(loc=(0.57, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={FT: HandlerLine2D(numpoints=3), RF: HandlerLine2D(numpoints=3)}, handletextpad=0.5, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_FR.get_lines()]


FF, = ax4.plot(timeS_FF, temp_FF[0,x,:], linewidth=5, linestyle='-',  color = 'tomato', label =r'FlatTop$\mathbf{_{\theta}}$')
BF, = ax4.plot(timeS_BF, temp_BF[0,x,:], linewidth=5, linestyle='--',  color='darkorchid', label=r'Bessel$\mathbf{_{\theta}}$')
ax4.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax4.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax4.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax4.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax4.set_ylim(100, 3100)
ax4.set_xlim(-2, 29)
ax4.spines[:].set_linewidth(4)
ax4.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_FB = ax4.legend(loc=(0.57, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={FF: HandlerLine2D(numpoints=3), BF: HandlerLine2D(numpoints=3)}, handletextpad=0.5, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_FB.get_lines()]

ax5 = fig.add_axes([0.4, 0.42, 0.20, 0.15], frameon=False) 
ax5.tick_params(axis='both', labelcolor='black', labelsize=1, bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False,)
hmap5 = ax5.imshow(temp_RF[:,:,275], cmap='rainbow', vmin=300, aspect=0.6,  interpolation='quadric')
ax5.plot(200, -60, marker='v', markersize=40, color='k')
# ax5.text(200,  40, "X", rotation=0, color='k', fontsize=45, weight='bold')
# ax5.set_ylim(201, -60)
# ax5.set_xlim(-1,401)
ax5.spines[:].set_linewidth(0)
ax5.add_patch(patches.Rectangle((0, -1), 400, 202, linewidth=2, edgecolor='k', facecolor='none'))


ax1.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax1.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')
ax2.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax2.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')
ax3.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax3.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')
ax4.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax4.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')

text_a = Text(x=0.06, y=0.90, text=r'(a)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')
text_b = Text(x=0.82, y=0.90, text=r'(b)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')
text_c = Text(x=0.06, y=0.45, text=r'(c)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')
text_d = Text(x=0.82, y=0.45, text=r'(d)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')

fig.add_artist(text_a)
fig.add_artist(text_b)
fig.add_artist(text_c)
fig.add_artist(text_d)

# plt.savefig('../../figures/Tt.png',bbox_inches='tight', dpi=800)
# plt.savefig('../../figures/jpg/Tt.jpg',bbox_inches='tight',)
# plt.savefig('../../../../0_GitHub_hostings/FreeEnergy_Benchmark_Model/2_Post_Processing/figures/Tt.png',bbox_inches='tight', dpi=800)
# plt.savefig('../../../../0_GitHub_hostings/FreeEnergy_Benchmark_Model/2_Post_Processing/figures/jpg/Tt.jpg',bbox_inches='tight',)
            
plt.show()

# %% [markdown]
# ### With proper HS marking

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=[16, 12], frameon=False)
ax1.set_facecolor((0, 0, 0, 0))
ax2.set_facecolor((0, 0, 0, 0))
ax3.set_facecolor((0, 0, 0, 0))
ax4.set_facecolor((0, 0, 0, 0))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.35, hspace=0.5)

x = int((401/1000)*500) # x-coordinate of point of interest
y = 0 # y coordinate of point of interest ## origin is at top left corner

GT, = ax1.plot(timeS_GT, temp_GT[0,200,:], linewidth=5, linestyle='-',  color='blue', label=r'Gaussian$\mathbf{_{\psi}}$')
RT, = ax1.plot(timeS_RT, temp_RT[0,200,:], linewidth=5, linestyle='--',  color = 'r', label =r'Ring$\mathbf{_{\psi}}$')
ax1.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax1.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax1.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax1.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax1.set_ylim(100, 3100)
ax1.set_xlim(-2, 29)
ax1.spines[:].set_linewidth(4)
ax1.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_GR = ax1.legend(loc=(0.55, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={GT: HandlerLine2D(numpoints=3), RT: HandlerLine2D(numpoints=3)}, handletextpad=0.1, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_GR.get_lines()]

GF, = ax2.plot(timeS_GF, temp_GF[0,200,:], linewidth=5, linestyle='-',  color = 'green', label =r'Gaussian$\mathbf{_{\theta}}$')
BT, = ax2.plot(timeS_BT, temp_BT[0,200,:], linewidth=5, linestyle='--',  color='hotpink', label=r'Bessel$\mathbf{_{\psi}}$')
ax2.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax2.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax2.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax2.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax2.set_ylim(100, 3100)
ax2.set_xlim(-2, 29)
ax2.spines[:].set_linewidth(4)
ax2.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_GB = ax2.legend(loc=(0.55, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={GF: HandlerLine2D(numpoints=3), BT: HandlerLine2D(numpoints=3)}, handletextpad=0.1, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_GB.get_lines()]


FT, = ax3.plot(timeS_FT, temp_FT[0,200,:], linewidth=5, linestyle='-',  color = 'darkorange', label =r'FlatTop$\mathbf{_{\psi}}$')
RF, = ax3.plot(timeS_RF, temp_RF[0,200,:], linewidth=5, linestyle='--',  color='navy', label=r'Ring$\mathbf{_{\theta}}$')
ax3.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax3.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax3.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax3.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax3.set_ylim(100, 3100)
ax3.set_xlim(-2, 29)
ax3.spines[:].set_linewidth(4)
ax3.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_FR = ax3.legend(loc=(0.57, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={FT: HandlerLine2D(numpoints=3), RF: HandlerLine2D(numpoints=3)}, handletextpad=0.5, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_FR.get_lines()]


FF, = ax4.plot(timeS_FF, temp_FF[0,x,:], linewidth=5, linestyle='-',  color = 'tomato', label =r'FlatTop$\mathbf{_{\theta}}$')
BF, = ax4.plot(timeS_BF, temp_BF[0,x,:], linewidth=5, linestyle='--',  color='darkorchid', label=r'Bessel$\mathbf{_{\theta}}$')
ax4.set_ylabel(r"T [K] $\longrightarrow$", loc='center',  weight = 'bold', labelpad=0, size=30, color='k')
ax4.set_xlabel(r"t [s]$ \mathbf{\longrightarrow}$", loc='center',  weight = 'bold', labelpad=10, size=30, color='k')
ax4.set_xticks([0, 5, 10, 15, 20, 25], labels=['0', '5', '10', '15', '20', '25'], size=20, weight='bold', color='k')
ax4.set_yticks([300, 1_200, 2_100, 3_000], labels=['300', '1200', '2100', '3000'], size=20, color='k', weight='bold')
ax4.set_ylim(100, 3100)
ax4.set_xlim(-2, 29)
ax4.spines[:].set_linewidth(4)
ax4.tick_params(axis='both', which='both', direction='inout', length=15, width=3, color='k')
legend_FB = ax4.legend(loc=(0.57, 0.67), ncol=1,  columnspacing=1.0, prop={'weight':'bold', 'size':'18', 'family': 'ADLaM Display'}, handler_map={FF: HandlerLine2D(numpoints=3), BF: HandlerLine2D(numpoints=3)}, handletextpad=0.5, handlelength=2.5, handleheight=1, edgecolor="black", facecolor='None', frameon=True)
[line.set_linewidth(5) for line in legend_FB.get_lines()]

ax5 = fig.add_axes([0.4, 0.42, 0.20, 0.15], frameon=False) 
ax5.tick_params(axis='both', labelcolor='black', labelsize=1, bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False,)
hmap5 = ax5.imshow(temp_RF[:,:,275], cmap='Spectral_r', vmin=300, aspect=0.6,  interpolation='quadric')
ax5.plot(200, -60, marker='v', markersize=40, color='red')
# ax5.text(200,  40, "X", rotation=0, color='k', fontsize=45, weight='bold')
# ax5.set_ylim(201, -60)
# ax5.set_xlim(-1,401)
ax5.spines[:].set_linewidth(0)
ax5.add_patch(patches.Rectangle((0, -1), 400, 202, linewidth=2, edgecolor='k', facecolor='none'))


ax1.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax1.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')
ax2.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax2.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')
ax3.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax3.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')
ax4.text(20, 1337-60, f"{1337} K", rotation=0, color='brown', fontsize=20, weight='bold', backgroundcolor='white',)
ax4.hlines(y=1337, xmin=-2, xmax=30, linestyle='--', linewidth=3, color='red')

text_a = Text(x=0.14, y=0.82, text=r'(a)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')
text_b = Text(x=0.585, y=0.82, text=r'(b)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')
text_c = Text(x=0.14, y=0.35, text=r'(c)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')
text_d = Text(x=0.585, y=0.35, text=r'(d)', fontsize=55, color='k', rotation=0, weight='bold', fontname='Play')

fig.add_artist(text_a)
fig.add_artist(text_b)
fig.add_artist(text_c)
fig.add_artist(text_d)

name_G = Text(x=0.92, y=0.62, text=r'Gaussian$\Downarrow$', fontsize=45, color='k', rotation=270, weight='bold', fontname='ADLaM Display')
name_F = Text(x=0.92, y=0.17, text=r'Flat Top$\Downarrow$', fontsize=45, color='k', rotation=270, weight='bold', fontname='ADLaM Display')
name_R = Text(x=0.24, y=0.91, text=r'Ring$\Downarrow$', fontsize=45, color='k', rotation=0, weight='bold', fontname='ADLaM Display')
name_B = Text(x=0.67, y=0.91, text=r'Bessel$\Downarrow$', fontsize=45, color='k', rotation=0, weight='bold', fontname='ADLaM Display')
fig.add_artist(name_G)
fig.add_artist(name_F)
fig.add_artist(name_R)
fig.add_artist(name_B)

# plt.savefig('../../figures/Tt.png',bbox_inches='tight', dpi=800)
# plt.savefig('../../figures/jpg/Tt.jpg',bbox_inches='tight',)
# plt.savefig('../../../../0_GitHub_hostings/FreeEnergy_Benchmark_Model/2_Post_Processing/figures/Tt.png',bbox_inches='tight', dpi=800)
# plt.savefig('../../../../0_GitHub_hostings/FreeEnergy_Benchmark_Model/2_Post_Processing/figures/jpg/Tt.jpg',bbox_inches='tight',)
            
plt.show()

# %%
print(temp_GT[0,200,:].max())
print(temp_GF[0,200,:].max())
print('\n')
print(temp_FT[0,200,:].max())
print(temp_FF[0,200,:].max())
print('\n')
print(temp_RT[0,200,:].max())
print(temp_RF[0,200,:].max())
print('\n')
print(temp_BT[0,200,:].max())
print(temp_BF[0,200,:].max())
# Out:
# 2873.292605768212
# 2933.987753571129
#
#
# 2843.0229073137302
# 2900.084619680943
#
#
# 1975.980840680701
# 1967.2496556449012
#
#
# 2550.2438430589186
# 2614.452717985121

# %%
Gaussian $_\psi$ : 2873.29
Gaussian $_\theta$ : 2933.98


FlatTop $_\psi$ :2843.02
FlatTop $_\theta$ :2900.08


Ring $_\psi$ :1975.98
Ring $_\theta$ :1967.24


Bessel $_\psi$ :2550.24
Bessel $_\theta$ :2614.45

# %%
np.argmax(temp_RT[0,200,:]),  timeS_RT[241], (timeS_RT[241]-12.5)*30
# Out:
# (241, 14.460000000000031, 58.800000000000935)

# %%
fig, ax1 = plt.subplots(1, 1, figsize=[8, 6], frameon=False)
ax1.set_facecolor((0, 0, 0, 0))

# ax1.plot(timeS_GT, temp_GT[0,200,:], linestyle='-', linewidth=4, color='red', label=r'GHS$\mathbf{_{\psi}}$')
ax1.plot(timeS_RF[:], temp_RF[0,200,:], linestyle='-', linewidth=2, color='red', label=r'RHS$\mathbf{_{\psi}}$')
ax1.plot(timeS_RF[243:307], temp_RF[0,200,243:307], linestyle='-', linewidth=6, color='k', label=r'RHS$\mathbf{_{\psi}}$')
ax1.hlines(xmin=0, xmax=28, y =1958)

# %%
timeS_RF[243:307], temp_RF[0,200,243:307].mean()
# Out:
# (array([10.61484375, 10.67484375, 10.73484375, 10.79484375, 10.85484375,
#         10.91484375, 10.97484375, 11.03484375, 11.09484375, 11.15484375,
#         11.21484375, 11.27484375, 11.33484375, 11.39484375, 11.45484375,
#         11.51484375, 11.57484375, 11.63484375, 11.69484375, 11.75484375,
#         11.81484375, 11.87484375, 11.93484375, 11.99484375, 12.05484375,
#         12.11484375, 12.17484375, 12.23484375, 12.29484375, 12.35484375,
#         12.41484375, 12.47484375, 12.53484375, 12.59484375, 12.65484375,
#         12.71484375, 12.77484375, 12.83484375, 12.89484375, 12.95484375,
#         13.01484375, 13.07484375, 13.13484375, 13.19484375, 13.25484375,
#         13.31484375, 13.37484375, 13.43484375, 13.49484375, 13.55484375,
#         13.61484375, 13.67484375, 13.73484375, 13.79484375, 13.85484375,
#         13.91484375, 13.97484375, 14.03484375, 14.09484375, 14.15484375,
#         14.21484375, 14.27484375, 14.33484375, 14.39484375]),
#  1958.0978441239563)
